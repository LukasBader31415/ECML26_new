# %%
from pathlib import Path
import shutil

repo_dir = Path.cwd()   # falls dein Notebook in scripts/ liegt
zip_base = repo_dir.parent / repo_dir.name  # ergibt .../ecml26-m3glvq.zip

# %%
zip_base
# Out:
# PosixPath('/home/lbader/USA/GeoFiles')

# %%
archive_path = shutil.make_archive(
    base_name=str(zip_base),
    format="zip",
    root_dir=str(repo_dir),
)

print("ZIP erstellt:", archive_path)
# Out:
# ZIP erstellt: /home/lbader/USA/GeoFiles.zip
